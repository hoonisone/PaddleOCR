# %% [markdown]
# Grapheme vs Character (Acc, C_NED, G_NED)

# %%
from database import *
import pandas as pd
import matplotlib.pyplot as plt
workdb = WorkDB()
window = 5
plt = workdb.draw_rec_graph_v2("rec_grapheme_full_horizontal_C_v1.0", window=window, metrics = [f"C|Character|Acc|O", f"C|Character|C_NED|O", f"C|Character|G_NED|O", f"C|First|Acc|O", f"C|Second|Acc|O", f"C|Third|Acc|O"], tasks=["test"], labels = ["C_C"], titles = ["ACC", "C_NED", "G_NED",  "First_Acc", "Second_Acc", "Third_Acc"], color='#ff7f0e')
plt = workdb.draw_rec_graph_v2("rec_grapheme_full_horizontal_G_v1.0", window=window, metrics = [f"G|Character|Acc|O", f"G|Character|C_NED|O", f"G|Character|G_NED|O", f"G|First|Acc|O", f"G|Second|Acc|O", f"G|Third|Acc|O"], tasks=["test"], labels = ["G_G"], titles = ["ACC", "C_NED", "G_NED",  "First_Acc", "Second_Acc", "Third_Acc"], color='#bcbd22')
plt = workdb.draw_rec_graph_v2("rec_grapheme_full_horizontal_C_v1.0", window=window, metrics = [f"C|Character|Acc|X", f"C|Character|C_NED|X", f"C|Character|G_NED|X", f"C|First|Acc|X", f"C|Second|Acc|X", f"C|Third|Acc|X"], tasks=["test"], labels = ["C_C_Space_Ignore"], titles = ["ACC", "C_NED", "G_NED",  "First_Acc", "Second_Acc", "Third_Acc"], linestyle="--", color='#ff7f0e')
plt = workdb.draw_rec_graph_v2("rec_grapheme_full_horizontal_G_v1.0", window=window, metrics = [f"G|Character|Acc|X", f"G|Character|C_NED|X", f"G|Character|G_NED|X", f"G|First|Acc|X", f"G|Second|Acc|X", f"G|Third|Acc|X"], tasks=["test"], labels = ["G_G_Space_Ignore"], titles = ["ACC", "C_NED", "G_NED",  "First_Acc", "Second_Acc", "Third_Acc"], linestyle="--", color='#bcbd22')


plt.gcf().set_size_inches(25, 5)
plt.show()

# %% [markdown]
# Support from Grapheme for Character

# %%
from database import *
import pandas as pd
import matplotlib.pyplot as plt
workdb = WorkDB()
window = 5
plt = workdb.draw_rec_graph_v2("rec_grapheme_full_horizontal_C+FML_v1.0", window=window, metrics = [f"C|Character|Acc|O", f"C|Character|C_NED|O", f"C|Character|G_NED|O", f"C|First|Acc|O", f"C|Second|Acc|O", f"C|Third|Acc|O"], tasks=["test"], labels = ["G+FML_C"], titles = ["ACC", "C_NED", "G_NED",  "First_Acc", "Second_Acc", "Third_Acc"], color='#d62728')
plt = workdb.draw_rec_graph_v2("rec_grapheme_full_horizontal_C_v1.0", window=window, metrics = [f"C|Character|Acc|O", f"C|Character|C_NED|O", f"C|Character|G_NED|O", f"C|First|Acc|O", f"C|Second|Acc|O", f"C|Third|Acc|O"], tasks=["test"], labels = ["C_C"], titles = ["ACC", "C_NED", "G_NED",  "First_Acc", "Second_Acc", "Third_Acc"], color='#ff7f0e')
plt = workdb.draw_rec_graph_v2("rec_grapheme_full_horizontal_C+FML_v1.0", window=window, metrics = [f"C|Character|Acc|X", f"C|Character|C_NED|X", f"C|Character|G_NED|X", f"C|First|Acc|X", f"C|Second|Acc|X", f"C|Third|Acc|X"], tasks=["test"], labels = ["G+FML_C_Space_Ignore"], titles = ["ACC", "C_NED", "G_NED",  "First_Acc", "Second_Acc", "Third_Acc"], linestyle="--", color='#d62728')
plt = workdb.draw_rec_graph_v2("rec_grapheme_full_horizontal_C_v1.0", window=window, metrics = [f"C|Character|Acc|X", f"C|Character|C_NED|X", f"C|Character|G_NED|X", f"C|First|Acc|X", f"C|Second|Acc|X", f"C|Third|Acc|X"], tasks=["test"], labels = ["C_C_Space_Ignore"], titles = ["ACC", "C_NED", "G_NED",  "First_Acc", "Second_Acc", "Third_Acc"], linestyle="--", color='#ff7f0e')


plt.gcf().set_size_inches(25, 5)
plt.show()

# %% [markdown]
# Support from Character for Grapheme

# %%
from database import *
import pandas as pd
import matplotlib.pyplot as plt
workdb = WorkDB()
window = 5
plt = workdb.draw_rec_graph_v2("rec_grapheme_full_horizontal_C+FML_v1.0", window=window, metrics = [f"G|Character|Acc|O", f"G|Character|C_NED|O", f"G|Character|G_NED|O", f"G|First|Acc|O", f"G|Second|Acc|O", f"G|Third|Acc|O"], tasks=["test"], labels = ["C+FML_G"], titles = ["ACC", "C_NED", "G_NED",  "First_Acc", "Second_Acc", "Third_Acc"], color='#2ca02c')
plt = workdb.draw_rec_graph_v2("rec_grapheme_full_horizontal_G_v1.0", window=window, metrics = [f"G|Character|Acc|O", f"G|Character|C_NED|O", f"G|Character|G_NED|O", f"G|First|Acc|O", f"G|Second|Acc|O", f"G|Third|Acc|O"], tasks=["test"], labels = ["G_G"], titles = ["ACC", "C_NED", "G_NED",  "First_Acc", "Second_Acc", "Third_Acc"], color='#bcbd22')
plt = workdb.draw_rec_graph_v2("rec_grapheme_full_horizontal_C+FML_v1.0", window=window, metrics = [f"G|Character|Acc|X", f"G|Character|C_NED|X", f"G|Character|G_NED|X", f"G|First|Acc|X", f"G|Second|Acc|X", f"G|Third|Acc|X"], tasks=["test"], labels = ["C+FML_G_Space_Ignore"], titles = ["ACC", "C_NED", "G_NED",  "First_Acc", "Second_Acc", "Third_Acc"], linestyle="--", color='#2ca02c')
plt = workdb.draw_rec_graph_v2("rec_grapheme_full_horizontal_G_v1.0", window=window, metrics = [f"G|Character|Acc|X", f"G|Character|C_NED|X", f"G|Character|G_NED|X", f"G|First|Acc|X", f"G|Second|Acc|X", f"G|Third|Acc|X"], tasks=["test"], labels = ["G_G_Space_Ignore"], titles = ["ACC", "C_NED", "G_NED",  "First_Acc", "Second_Acc", "Third_Acc"], linestyle="--", color='#bcbd22')


plt.gcf().set_size_inches(25, 5)
plt.show()

# %% [markdown]
# Supported Grapheme vs Character

# %%
from database import *
import pandas as pd
import matplotlib.pyplot as plt
workdb = WorkDB()
window = 5
plt = workdb.draw_rec_graph_v2("rec_grapheme_full_horizontal_C+FML_v1.0", window=window, metrics = [f"C|Character|Acc|O", f"C|Character|C_NED|O", f"C|Character|G_NED|O", f"C|First|Acc|O", f"C|Second|Acc|O", f"C|Third|Acc|O"], tasks=["test"], labels = ["G+FML_C"], titles = ["ACC", "C_NED", "G_NED",  "First_Acc", "Second_Acc", "Third_Acc"], color='#d62728')
plt = workdb.draw_rec_graph_v2("rec_grapheme_full_horizontal_C+FML_v1.0", window=window, metrics = [f"G|Character|Acc|O", f"G|Character|C_NED|O", f"G|Character|G_NED|O", f"G|First|Acc|O", f"G|Second|Acc|O", f"G|Third|Acc|O"], tasks=["test"], labels = ["G+FML_G"], titles = ["ACC", "C_NED", "G_NED",  "First_Acc", "Second_Acc", "Third_Acc"], color='#2ca02c')
plt = workdb.draw_rec_graph_v2("rec_grapheme_full_horizontal_C+FML_v1.0", window=window, metrics = [f"C|Character|Acc|X", f"C|Character|C_NED|X", f"C|Character|G_NED|X", f"C|First|Acc|X", f"C|Second|Acc|X", f"C|Third|Acc|X"], tasks=["test"], labels = ["G+FML_C_Space_Ignore"], titles = ["ACC", "C_NED", "G_NED",  "First_Acc", "Second_Acc", "Third_Acc"], linestyle="--", color='#d62728')
plt = workdb.draw_rec_graph_v2("rec_grapheme_full_horizontal_C+FML_v1.0", window=window, metrics = [f"G|Character|Acc|X", f"G|Character|C_NED|X", f"G|Character|G_NED|X", f"G|First|Acc|X", f"G|Second|Acc|X", f"G|Third|Acc|X"], tasks=["test"], labels = ["G+FML_G_Space_Ignore"], titles = ["ACC", "C_NED", "G_NED",  "First_Acc", "Second_Acc", "Third_Acc"], linestyle="--", color='#2ca02c')


plt.gcf().set_size_inches(25, 50)
plt.show()

# %%
from pathlib import Path
from PIL import Image

with open(Path("/home/test_dataset/AIHub_test/unseen/label.txt")) as f:
    lines = f.readlines()
    lines = [line.split("\t") for line in lines]
    
for path, label in lines:
    Image.open(Path("/home/datasets/")/path).resize((200, 100)).show()
    print("/".join(path.split("/")[1:]), "\t", label)
# Out:
# <PIL.Image.Image image mode=RGB size=200x100>
# 520/519903.png 	 잽주다
# <PIL.Image.Image image mode=RGB size=200x100>
# 715/714557.png 	 됀장찌개
# <PIL.Image.Image image mode=RGB size=200x100>
# 830/829207.png 	 이뤄내는
# <PIL.Image.Image image mode=RGB size=200x100>
# 878/877857.png 	 기욤 뮈소 장편소설
# <PIL.Image.Image image mode=RGB size=200x100>
# 832/831093.png 	 교사가 알아야 핦
# <PIL.Image.Image image mode=RGB size=200x100>
# 877/876978.png 	 건넜어
# <PIL.Image.Image image mode=RGB size=200x100>
# 616/615367.png 	 캌테일
# <PIL.Image.Image image mode=RGB size=200x100>
# 298/297402.png 	 모틍이집
# <PIL.Image.Image image mode=RGB size=200x100>
# 792/791981.png 	 크림브륄레
# <PIL.Image.Image image mode=RGB size=200x100>
# 354/353829.png 	 맬번
# <PIL.Image.Image image mode=RGB size=200x100>
# 791/790992.png 	 텁텁한 맛을 제거한
# <PIL.Image.Image image mode=RGB size=200x100>
# 205/204064.png 	 뻭다방
# <PIL.Image.Image image mode=RGB size=200x100>
# 40/39753.png 	 븍창동순
# <PIL.Image.Image image mode=RGB size=200x100>
# ...
