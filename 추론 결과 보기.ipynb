# %%
from PIL import Image

path = "/home/works/rec_PPOCR_full_v1/inference_result"
path = "/home/works/rec_PPOCR_full_auto_rotate_v1/inference_result"

with open(path) as f:
    lines = [line.rstrip("\n").split("\t") for line in f.readlines()]

for path, label, p in lines[:100]:
    image = Image.open(path)
    image.show()
    print(label, p)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=259x543>
# xe 0.1033143550157547
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=233x1926>
#  회 0.3347715437412262
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=154x234>
# 타이 0.997891366481781
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=67x466>
# 236 0.3064476251602173
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x217>
# 03 0.09578786790370941
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=144x225>
# 수림 0.9692648649215698
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=187x698>
# IMA  0.36516162753105164
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=178x1424>
# 3UEM SS-S 0.247940331697464
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=33x77>
# 1o 0.4729112386703491
