# %% [markdown]
# # Dataset

# %%
from database import *
datasetdb = DatasetDB()
datasetdb.get_df()
# Out:
#                                   id   task    size
# 0                      sangmu_str_MH  [STR]     501
# 0                      sangmu_str_DI  [STR]     568
# 0                      sangmu_str_DH  [STR]     566
# 0                      sangmu_std_MH  [STD]     501
# 0                      sangmu_std_DI  [STD]     568
# 0                      sangmu_std_DH  [STD]     566
# 0                   sangmu_str_MH_v2  [STR]    1491
# 0                   sangmu_str_DI_v2  [STR]    1840
# 0                   sangmu_str_DH_v2  [STR]    2208
# 0                          aihub_rec  [STR]  682525
# 0                           rec_test  [STR]       3
# 0                           rec_SVTP  [STR]     645
# 0                            rec_SVT  [STR]     647
# 0                         rec_IIIT5K  [STR]    5000
# 0                           rec_ic15  [STR]    2077
# 0                           rec_ic13  [STR]     857
# 0                           rec_ic03  [STR]     860
# ...

# %%
datasetdb.get_all_id()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3870954/2094839696.py in <module>
# ----> 1 datasetdb.get_all_id()
#
# NameError: name 'datasetdb' is not defined
