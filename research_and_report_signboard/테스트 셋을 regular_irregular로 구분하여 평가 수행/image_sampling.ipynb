# %% [markdown]
# ### Regular Iregular 각각 대표적인 샘플 뽑기

# %%
import enum
from PIL import Image
from pathlib import Path
regular_path = "/home/research/테스트 셋을 regular_irregular로 구분하여 평가 수행/regular.txt"
with open(regular_path) as f:
    lines = [l.rstrip("\n").split("\t") for l in f.readlines()]

# Image.open(Path("/home/datasets/")/lines[0][0]).show()
# Image.open(Path("/home/datasets/")/lines[5][0]).show()
# Image.open(Path("/home/datasets/")/lines[6][0]).show()
# Image.open(Path("/home/datasets/")/lines[9][0]).show()
# Image.open(Path("/home/datasets/")/lines[10][0]).show()

for i, idx in enumerate([0, 5, 6, 9, 10]):
    Image.open(Path("/home/datasets/")/lines[idx][0]).save(f"regular_{i}.png")

# %%
regular_path = "/home/research/테스트 셋을 regular_irregular로 구분하여 평가 수행/irregular.txt"
with open(regular_path) as f:
    lines = [l.rstrip("\n").split("\t") for l in f.readlines()]



for i, idx in enumerate([0, 6, 7, 12, 14]):
    Image.open(Path("/home/datasets/")/lines[idx][0]).show()
    Image.open(Path("/home/datasets/")/lines[idx][0]).save(f"irregular_{i}.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=128x60>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=147x80>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=760x188>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1198x937>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1778x914>
